# %% [markdown]
# <a href="https://colab.research.google.com/github/Pankajsahuiq2/Student_attendance_tracker/blob/main/hw_ml01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##
#
# ---
#
# ---
#
#
#   #                 *: : : : : : : : : HOMEWORK : : : : : : : : *
#
# ---
#
#
#
# ---
#
# ##Date = 13/04/25

# %%
import seaborn as sns
import pandas as pd
ds = pd.read_csv('Salary_Data.csv')
ds
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %% [markdown]
# ## ~>Data Information phase (Knowing about data)

# %%
ds.shape
# Out:
# (30, 2)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
ds.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
ds.tail()
# Out:
#     YearsExperience    Salary
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %% [markdown]
# ### NO modification or removing of data required as there is no null values or black values and the data is already sorted on the basis of experience in ascending order

# %%
ds.describe() #Provide statistical Information of given data
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
ds.corr(method='pearson')
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
sns.displot(data=ds,x='YearsExperience',y='Salary')

# %%
sns.scatterplot(data=ds,x='YearsExperience',y='Salary')
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
sns.lmplot(data=ds,x='YearsExperience',y='Salary')

# %% [markdown]
# ## 1st method
#
# ---
#
#
#
# ---

# %%
from sklearn.linear_model import LinearRegression
rg = LinearRegression()

# %%
ds.YearsExperience.values
# Out:
# array([ 1.1,  1.3,  1.5,  2. ,  2.2,  2.9,  3. ,  3.2,  3.2,  3.7,  3.9,
#         4. ,  4. ,  4.1,  4.5,  4.9,  5.1,  5.3,  5.9,  6. ,  6.8,  7.1,
#         7.9,  8.2,  8.7,  9. ,  9.5,  9.6, 10.3, 10.5])

# %%
ds.YearsExperience.values.reshape(-1,1)
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
x = ds.YearsExperience.values.reshape(-1,1)
rg.fit(x,ds.Salary)
# Out:
# LinearRegression()

# %%
ds[['YearsExperience']]
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
rg.fit(ds[['YearsExperience']],ds.Salary)
# Out:
# LinearRegression()

# %%
rg.predict([[15]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([167541.63502049])

# %%
rg.predict([[15],[19]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([167541.63502049, 205341.48430632])

# %%
rg.predict([[19]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([205341.48430632])

# %%
from sklearn.metrics import r2_score
y_origional = ds.Salary
y_predicted = rg.predict(ds[['YearsExperience']])
R_square = r2_score(y_origional,y_predicted)
print('R2 score value is =',R_square)
# Out:
# R2 score value is = 0.9569566641435086

# %% [markdown]
# ## 2nd method
#
# ---
#
#
#
# ---

# %%
from sklearn.model_selection import train_test_split
x = ds[['YearsExperience']]
y = ds.Salary
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.01,random_state=2)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)
y_pred
# Out:
# array([37150.94644095])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# nan

# %%
sns.scatterplot(x_train,y_train, color='red')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-578c78c6576c> in <cell line: 0>()
# ----> 1 sns.scatterplot(x_train,y_train, color='red')
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 were given

# %%
sns.lmplot(x_train,lr.predict(x_train), color='blue')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-41535baa0556> in <cell line: 0>()
# ----> 1 sns.lmplot(x_train,lr.predict(x_train), color='blue')
#
# TypeError: lmplot() got an unexpected keyword argument 'color'

# %%
lr.predict([[15]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([168746.90556895])

# %%
lr.predict([[15],[19]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([168746.90556895, 207169.08341654])

# %%
lr.predict([[19]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([207169.08341654])

# %%
from sklearn.metrics import r2_score
R_square = r2_score(y_test,y_pred)
print('R2 score value is =',R_square)
# Out:
# R2 score value is = nan
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)

# %% [markdown]
# ## Trying with different train test sizes

# %% [markdown]
# ### ~> test_size=0.1

# %%
from sklearn.model_selection import train_test_split
x = ds[['YearsExperience']]
y = ds.Salary
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1,random_state=3)

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pre = lm.predict(x_test)
y_pre
# Out:
# array([ 72083.41285844,  53143.78955629, 100492.84781165])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pre)
# Out:
# 0.9721105483403136

# %% [markdown]
# ### OMG! accuracy is 97%

# %%
lm.predict([[15]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([167728.51053426])

# %%
lm.predict([[15],[19]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([167728.51053426, 205607.75713855])

# %% [markdown]
# i don't know why it's still not plotting anything

# %%
sns.scatterplot(x_train,y_train, color='red')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-578c78c6576c> in <cell line: 0>()
# ----> 1 sns.scatterplot(x_train,y_train, color='red')
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 were given

# %%
sns.plot(x_train,lm.predict(x_train), color='blue')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-56e2ae8dafb8> in <cell line: 0>()
# ----> 1 sns.plot(x_train,lm.predict(x_train), color='blue')
#
# AttributeError: module 'seaborn' has no attribute 'plot'

# %% [markdown]
# ### ~> test_size = 0.2

# %%
from sklearn.model_selection import train_test_split
x = ds[['YearsExperience']]
y = ds.Salary
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
re = LinearRegression()
re.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pr = re.predict(x_test)
y_pr
# Out:
# array([75074.50510972, 91873.8056381 , 62008.38247653, 81607.56642631,
#        67608.14931932, 89073.92221671])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pr)
# Out:
# 0.7616681465472094

# %% [markdown]
# ### OOP's in this one we only got 76% accuracy

# %%
re.predict([[15]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([165604.06906825])

# %%
re.predict([[19]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([202935.84802022])

# %% [markdown]
# ### ~> train_size = 0.5

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split( ds[['YearsExperience']], ds.Salary, train_size=0.5)

# %%
from sklearn.linear_model import LinearRegression
r = LinearRegression()
r.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = r.predict(x_test)
y_pred
# Out:
# array([ 55067.29918508, 124712.45105068,  52124.54628936, 111960.52183586,
#        101170.42788485,  43296.28760217,  38391.69944262,  75666.56945519,
#        117846.02762732,  82532.99287856,  36429.8641788 ,  59971.88734463,
#         63895.55787227,  61933.72260845,  71742.89892755])

# %%
from sklearn.metrics import r2_score
r2_score()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-296aaf02e09e> in <cell line: 0>()
#       1 from sklearn.metrics import r2_score
# ----> 2 r2_score()
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     192
#     193             # Map *args/**kwargs to the function signature
# --> 194             params = func_sig.bind(*args, **kwargs)
#     195             params.apply_defaults()
#     196
#
# /usr/lib/python3.11/inspect.py in bind(self, *args, **kwargs)
#    3193         if the passed arguments can not be bound.
#    3194         """
# -> 3195         return self._bind(args, kwargs)
#    3196
#    3197     def bind_partial(self, /, *args, **kwargs):
#
# /usr/lib/python3.11/inspect.py in _bind(self, args, kwargs, partial)
# ...
